# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import optuna
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import KNNImputer
from tqdm.notebook import tqdm

# %%
df = pd.read_csv("train.csv")

# %%
df["Sex"] = df["Sex"].map({"male": 0, "female": 1})

# %%
df["Embarked"] = df["Embarked"].fillna("S")
emb_dummies = pd.get_dummies(df["Embarked"], prefix="Embarked", drop_first=True)

# %%
df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)
df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 
                                   'Sir','Jonkheer','Dona'],'Rare')
df['Title'] = df['Title'].map({'Mr':0,'Miss':1,'Mrs':2,'Master':3,'Rare':4})
df['Title'] = df['Title'].fillna(0)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# <>:1: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\39392\AppData\Local\Temp\ipykernel_12744\3116080038.py:1: SyntaxWarning: invalid escape sequence '\.'
#   df['Title'] = df['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

# %%
# FamilySize
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
X = df[['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'FamilySize', 'Title']].join(emb_dummies)
y = df['Survived']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=41, stratify=y)

# %%
def objective(trial):
    params = {
        'objective': 'binary:logistic',
        'n_estimators': trial.suggest_int('n_estimators', 100, 2000),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 15),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 1e-8, 10.0, log=True),
        'reg_lambda': trial.suggest_float('reg_lambda', 1e-8, 10.0, log=True),
        'tree_method': 'hist',
        'device': 'cuda',
        'random_state': 41,
        'n_jobs': -1
    }
    
    model = xgb.XGBClassifier(**params)
    cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    scores = cross_val_score(model, X_train, y_train, cv=cv, scoring='accuracy')
    return scores.mean()

# %%
from tqdm import tqdm

n_trials = 50
study = optuna.create_study(direction='maximize', study_name="XGBoost_Titanic")

for _ in tqdm(range(n_trials), desc="Optuna Trials"):
    study.optimize(objective, n_trials=1, show_progress_bar=False)
# Out:
# [I 2025-12-05 11:41:53,230] A new study created in memory with name: XGBoost_Titanic
# Optuna Trials:   0%|          | 0/50 [00:00<?, ?it/s]c:\Python312\Lib\site-packages\xgboost\core.py:774: UserWarning: [11:41:54] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\common\error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# [I 2025-12-05 11:41:58,223] Trial 0 finished with value: 0.7993806451612905 and parameters: {'n_estimators': 480, 'learning_rate': 0.025348545473143025, 'max_depth': 7, 'subsample': 0.6153218338601127, 'colsample_bytree': 0.5412839753871777, 'reg_alpha': 6.574295220334044e-06, 'reg_lambda': 0.17420322308870234}. Best is trial 0 with value: 0.7993806451612905.
# Optuna Trials:   2%|▏         | 1/50 [00:04<04:04,  4.99s/it][I 2025-12-05 11:42:14,678] Trial 1 finished with value: 0.8025935483870968 and parameters: {'n_estimators': 1078, 'learning_rate': 0.004019859388339389, 'max_depth': 13, 'subsample': 0.7786069757211693, 'colsample_bytree': 0.9525973621915714, 'reg_alpha': 0.04283174646848456, 'reg_lambda': 0.16599556804179388}. Best is trial 1 with value: 0.8025935483870968.
# Optuna Trials:   4%|▍         | 2/50 [00:21<09:23, 11.74s/it][I 2025-12-05 11:42:23,518] Trial 2 finished with value: 0.7881806451612904 and parameters: {'n_estimators': 863, 'learning_rate': 0.03924289700584488, 'max_depth': 8, 'subsample': 0.5520991545252487, 'colsample_bytree': 0.6291715620260596, 'reg_alpha': 1.673705248539143e-05, 'reg_lambda': 0.00013134198016114112}. Best is trial 1 with value: 0.8025935483870968.
# Optuna Trials:   6%|▌         | 3/50 [00:30<08:09, 10.41s/it][I 2025-12-05 11:42:40,265] Trial 3 finished with value: 0.7897806451612904 and parameters: {'n_estimators': 1456, 'learning_rate': 0.01929774211289791, 'max_depth': 15, 'subsample': 0.5949474849657712, 'colsample_bytree': 0.8242909780883558, 'reg_alpha': 1.2215538833435373e-08, 'reg_lambda': 0.5233308905658619}. Best is trial 1 with value: 0.8025935483870968.
# Optuna Trials
. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials:  86%|████████▌ | 43/50 [07:56<00:58,  8.30s/it][I 2025-12-05 11:49:56,299] Trial 43 finished with value: 0.8041548387096775 and parameters: {'n_estimators': 1076, 'learning_rate': 0.003592875535204199, 'max_depth': 3, 'subsample': 0.9636887281825697, 'colsample_bytree': 0.9070072001760917, 'reg_alpha': 0.2327230959940935, 'reg_lambda': 0.00015475608071585396}. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials:  88%|████████▊ | 44/50 [08:03<00:47,  7.92s/it][I 2025-12-05 11:50:05,307] Trial 44 finished with value: 0.8025290322580647 and parameters: {'n_estimators': 1248, 'learning_rate': 0.0018589759908414062, 'max_depth': 4, 'subsample': 0.8773818871583556, 'colsample_bytree': 0.8497519893731508, 'reg_alpha': 9.56810683515244, 'reg_lambda': 0.0006868321161988163}. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials:  90%|█████████ | 45/50 [08:12<00:41,  8.25s/it][I 2025-12-05 11:50:19,763] Trial 45 finished with value: 0.8090193548387099 and parameters: {'n_estimators': 1649, 'learning_rate': 0.00535491184547708, 'max_depth': 5, 'subsample': 0.9002329793243538, 'colsample_bytree': 0.9309477995886728, 'reg_alpha': 1.3799723582072474, 'reg_lambda': 1.2947870126793742e-05}. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials:  92%|█████████▏| 46/50 [08:26<00:40, 10.11s/it][I 2025-12-05 11:50:22,991] Trial 46 finished with value: 0.8105806451612902 and parameters: {'n_estimators': 415, 'learning_rate': 0.011774861848511056, 'max_depth': 6, 'subsample': 0.6012045768484604, 'colsample_bytree': 0.7193647208768178, 'reg_alpha': 3.7792075927115523, 'reg_lambda': 0.009370333172446866}. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials:  94%|█████████▍| 47/50 [08:29<00:24,  8.05s/it][I 2025-12-05 11:50:41,767] Trial 47 finished with value: 0.7705161290322581 and parameters: {'n_estimators': 1476, 'learning_rate': 0.01949863903030388, 'max_depth': 9, 'subsample': 0.9746291446356248, 'colsample_bytree': 0.8728860327663311, 'reg_alpha': 0.05938253717337156, 'reg_lambda': 7.3563508219226575e-06}. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials:  96%|█████████▌| 48/50 [08:48<00:22, 11.26s/it][I 2025-12-05 11:50:51,758] Trial 48 finished with value: 0.7881935483870969 and parameters: {'n_estimators': 1388, 'learning_rate': 0.03052614022889222, 'max_depth': 4, 'subsample': 0.7133061223643264, 'colsample_bytree': 0.9166091068928716, 'reg_alpha': 1.9707208668259907e-06, 'reg_lambda': 6.31654365074387e-07}. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials:  98%|█████████▊| 49/50 [08:58<00:10, 10.88s/it][I 2025-12-05 11:51:00,281] Trial 49 finished with value: 0.778541935483871 and parameters: {'n_estimators': 950, 'learning_rate': 0.12645148480387483, 'max_depth': 7, 'subsample': 0.9357624050179418, 'colsample_bytree': 0.8075841729729337, 'reg_alpha': 0.7735433210512334, 'reg_lambda': 0.0028921237858272253}. Best is trial 19 with value: 0.820232258064516.
# Optuna Trials: 100%|██████████| 50/50 [09:07<00:00, 10.94s/it]

# %%
print("\n--- Risultati Ottimizzazione ---")
print(f"Miglior Trial (Tentativo #{study.best_trial.number})")
print(f"Accuratezza Migliore (CV): {study.best_value:.4f}")
print("Migliori Iperparametri:")
for key, value in study.best_params.items():
    print(f"  {key}: {value}")
# Out:
# --- Risultati Ottimizzazione ---
# Miglior Trial (Tentativo #19)
# Accuratezza Migliore (CV): 0.8202
# Migliori Iperparametri:
#   n_estimators: 882
#   learning_rate: 0.07144478795218712
#   max_depth: 11
#   subsample: 0.8711115449940225
#   colsample_bytree: 0.8822594638701202
#   reg_alpha: 2.518522562541505
#   reg_lambda: 0.011206403555939475

# %%
best_params = study.best_params
final_model = xgb.XGBClassifier(**best_params, tree_method='gpu_hist', predictor='gpu_predictor',
                                random_state=41, n_jobs=-1)
final_model.fit(X_train, y_train)
final_acc = final_model.score(X_test, y_test)
print(f"\nAccuratezza Finale sul Test Set: {final_acc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Cell In[55], line 4
#       1 best_params = study.best_params
#       2 final_model = xgb.XGBClassifier(**best_params, tree_method='gpu_hist', predictor='gpu_predictor',
#       3                                 random_state=41, n_jobs=-1)
# ----> 4 final_model.fit(X_train, y_train)
#       5 final_acc = final_model.score(X_test, y_test)
#       6 print(f"\nAccuratezza Finale sul Test Set: {final_acc:.4f}")
#
# File c:\Python312\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Python312\Lib\site-packages\xgboost\sklearn.py:1806, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1786 evals_result: EvalsLog = {}
#    1787 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1788     missing=self.missing,
#    1789     X=X,
#    (...)   1803     feature_types=feature_types,
#    1804 )
# -> 1806 self._Booster = train(
#    1807     params,
#    1808     train_dmatrix,
#    1809     self.get_num_boosting_rounds(),
#    1810     evals=evals,
#    1811     early_stopping_rounds=self.early_stopping_rounds,
#    1812     evals_result=evals_result,
#    1813     obj=obj,
#    1814     custom_metric=metric,
#    1815     verbose_eval=verbose,
#    1816     xgb_model=model,
#    1817     callbacks=self.callbacks,
#    1818 )
#    1820 if not callable(self.objective):
#    1821     self.objective = params["objective"]
#
# File c:\Python312\Lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Python312\Lib\site-packages\xgboost\training.py:199, in train(params, dtrain, num_boost_round, evals, obj, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     197 if cb_container.before_iteration(bst, i, dtrain, evals):
#     198     break
# --> 199 bst.update(dtrain, iteration=i, fobj=obj)
#     200 if cb_container.after_iteration(bst, i, dtrain, evals):
#     201     break
#
# File c:\Python312\Lib\site-packages\xgboost\core.py:2433, in Booster.update(self, dtrain, iteration, fobj)
#    2430 self._assign_dmatrix_features(dtrain)
#    2432 if fobj is None:
# -> 2433     _check_call(
#    2434         _LIB.XGBoosterUpdateOneIter(
#    2435             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2436         )
#    2437     )
#    2438 else:
#    2439     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File c:\Python312\Lib\site-packages\xgboost\core.py:323, in _check_call(ret)
#     312 """Check the return value of C API call
#     313
#     314 This function will raise exception when error occurs.
#    (...)    320     return value from API calls
#     321 """
#     322 if ret != 0:
# --> 323     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: Invalid Input: 'gpu_hist', valid values are: {'approx', 'auto', 'exact', 'hist'}
